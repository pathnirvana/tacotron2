# %% [markdown]
# ## Tacotron 2 inference code
# Edit the variables **checkpoint_path** and **text** to match yours and run the entire code to generate plots of mel outputs, alignments and audio synthesis from the generated mel-spectrogram using Griffin-Lim.

# %% [markdown]
# #### Import libraries and setup matplotlib

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pylab as plt

import IPython.display as ipd

import sys
sys.path.append('waveglow/')
import numpy as np
import torch

from hparams import create_hparams
from model import Tacotron2
from layers import TacotronSTFT, STFT
from audio_processing import griffin_lim
from train import load_model
from text import text_to_sequence
from denoiser import Denoiser
# Out:
# /home/janaka/tacotron2/plotting_utils.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/janaka/my_venv3.6/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/janaka/my_venv3.6/lib/python3.6/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/home/janaka/my_venv3.6/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
# ...

# %%
def plot_data(data, figsize=(16, 4)):
    fig, axes = plt.subplots(1, len(data), figsize=figsize)
    for i in range(len(data)):
        axes[i].imshow(data[i], aspect='auto', origin='bottom', 
                       interpolation='none')

# %% [markdown]
# #### Setup hparams

# %%
hparams = create_hparams()
hparams.sampling_rate = 22050
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# #### Load model from checkpoint

# %%
print(text_to_sequence("jජනක", ['basic_cleaners']))
checkpoint_path = "/home/janaka/datasets/checkpoint_5000" #"tacotron2_statedict.pt"
model = load_model(hparams)
model.load_state_dict(torch.load(checkpoint_path)['state_dict'])
_ = model.cuda().eval().half()
# Out:
# [47, 64, 65, 66]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-ca92c7a1318b> in <module>
#       2 checkpoint_path = "/home/janaka/datasets/checkpoint_5000" #"tacotron2_statedict.pt"
#       3 model = load_model(hparams)
# ----> 4 model.load_state_dict(torch.load(checkpoint_path)['state_dict'])
#       5 _ = model.cuda().eval().half()
#
# ~/my_venv3.6/lib/python3.6/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#    1050         if len(error_msgs) > 0:
#    1051             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# -> 1052                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1053         return _IncompatibleKeys(missing_keys, unexpected_keys)
#    1054
#
# RuntimeError: Error(s) in loading state_dict for Tacotron2:
# ...

# %% [markdown]
# #### Load WaveGlow for mel2audio synthesis and denoiser

# %%
waveglow_path = "/home/janaka/datasets/waveglow_256channels_universal_v5.pt" #'waveglow_256channels.pt'
waveglow = torch.load(waveglow_path)['model']
waveglow.cuda().eval().half()
for k in waveglow.convinv:
    k.float()
denoiser = Denoiser(waveglow)

# %% [markdown]
# #### Prepare text input

# %%
text = "janaka" #"ජනක ප්‍රදීප් ලියනගේ"
sequence = np.array(text_to_sequence(text, ['basic_cleaners']))[None, :]
print(text_to_sequence("jජනක1", ['basic_cleaners']))
sequence = torch.autograd.Variable(
    torch.from_numpy(sequence)).cuda().long()
# Out:
# [47]

# %% [markdown]
# #### Decode text input and plot results

# %%
mel_outputs, mel_outputs_postnet, _, alignments = model.inference(sequence)
plot_data((mel_outputs.float().data.cpu().numpy()[0],
           mel_outputs_postnet.float().data.cpu().numpy()[0],
           alignments.float().data.cpu().numpy()[0].T))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-2e5552ce83d1> in <module>
# ----> 1 mel_outputs, mel_outputs_postnet, _, alignments = model.inference(sequence)
#       2 plot_data((mel_outputs.float().data.cpu().numpy()[0],
#       3            mel_outputs_postnet.float().data.cpu().numpy()[0],
#       4            alignments.float().data.cpu().numpy()[0].T))
#
# ~/tacotron2/model.py in inference(self, inputs)
#     517     def inference(self, inputs):
#     518         embedded_inputs = self.embedding(inputs).transpose(1, 2)
# --> 519         encoder_outputs = self.encoder.inference(embedded_inputs)
#     520         mel_outputs, gate_outputs, alignments = self.decoder.inference(
#     521             encoder_outputs)
#
# ~/tacotron2/model.py in inference(self, x)
#     192     def inference(self, x):
#     193         for conv in self.convolutions:
# ...

# %% [markdown]
# #### Synthesize audio from spectrogram using WaveGlow

# %%
with torch.no_grad():
    audio = waveglow.infer(mel_outputs_postnet, sigma=0.666)
ipd.Audio(audio[0].data.cpu().numpy(), rate=hparams.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### (Optional) Remove WaveGlow bias

# %%
audio_denoised = denoiser(audio, strength=0.01)[:, 0]
ipd.Audio(audio_denoised.cpu().numpy(), rate=hparams.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
